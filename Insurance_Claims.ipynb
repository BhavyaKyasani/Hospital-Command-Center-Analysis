# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavyaKyasani/Hospital-Command-Center-Analysis/blob/main/Insurance_Claims.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
sns.set(font_scale=1)

import warnings
warnings.filterwarnings("ignore")

# %%
path = "/content/enhanced_health_insurance_claims_FINAL_20000 (1).csv"

df = pd.read_csv(path)

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (20000, 17)

# %%
print("First 5 Rows")
display(df.head())

print("Last 5 Rows")
display(df.tail())
# Out:
# First 5 Rows
#                                 ClaimID                             PatientID  \
# 0  10944daf-f7d5-4e1d-8216-72ffa609fe41  8552381d-7960-4f64-b190-b20b8ada00a1
# 1  fcbebb25-fc24-4c0f-a966-749edcf83fb1  327f43ad-e3bd-4473-a9ed-46483a0a156f
# 2  9e9983e7-9ea7-45f5-84d8-ce49ccd8a4a1  6f3acdf7-73aa-4afa-9c2e-b25b27bdb5b0
# 3  a06273ed-44bb-452b-bbad-8618de080494  5d58e183-701e-406c-a8c6-5b73cac5e912
# 4  f702a717-254b-4cff-a0c7-8395db2f6616  8a8ebdf6-3af0-4f14-82f3-37b937c3d270
#
#                              ProviderID  ClaimAmount   ClaimDate  \
# 0  4a4cb19c-4863-41cf-84b0-c2b21aace988      3807.95  2024-06-07
# 1  422e02dd-c1fd-43dd-8af4-0c3523f997b1      9512.07  2023-05-30
# 2  f7733b3f-0980-47b5-a7a0-ee390869355b      7346.74  2022-09-27
# 3  f7a04581-de96-44ee-b773-8adac02baa59      6026.72  2023-06-25
# 4  b80b9e77-97f0-47d7-b561-19f9658a7bdf      1644.58  2023-07-24
#
#   DiagnosisCode ProcedureCode  PatientAge PatientGender ProviderSpecialty  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ClaimID                  20000 non-null  object
#  1   PatientID                20000 non-null  object
#  2   ProviderID               20000 non-null  object
#  3   ClaimAmount              20000 non-null  float64
#  4   ClaimDate                20000 non-null  object
#  5   DiagnosisCode            20000 non-null  object
#  6   ProcedureCode            20000 non-null  object
#  7   PatientAge               20000 non-null  int64
#  8   PatientGender            20000 non-null  object
#  9   ProviderSpecialty        4500 non-null   object
#  10  ClaimStatus              20000 non-null  object
#  11  PatientIncome            4500 non-null   float64
#  12  PatientMaritalStatus     4500 non-null   object
#  13  PatientEmploymentStatus  4500 non-null   object
# ...

# %%
print(df.dtypes)
# Out:
# ClaimID                     object
# PatientID                   object
# ProviderID                  object
# ClaimAmount                float64
# ClaimDate                   object
# DiagnosisCode               object
# ProcedureCode               object
# PatientAge                   int64
# PatientGender               object
# ProviderSpecialty           object
# ClaimStatus                 object
# PatientIncome              float64
# PatientMaritalStatus        object
# PatientEmploymentStatus     object
# ProviderLocation            object
# ClaimType                   object
# ClaimSubmissionMethod       object
# dtype: object

# %%
display(df.describe(include='all'))
# Out:
#             ClaimID  PatientID                            ProviderID  \
# count         20000      20000                                 20000
# unique        20000      18132                                  4500
# top     CLM99556443  PAT001475  89017a6b-8963-456e-a243-8ad4d0dbb81e
# freq              1          6                                    13
# mean            NaN        NaN                                   NaN
# std             NaN        NaN                                   NaN
# min             NaN        NaN                                   NaN
# 25%             NaN        NaN                                   NaN
# 50%             NaN        NaN                                   NaN
# 75%             NaN        NaN                                   NaN
# max             NaN        NaN                                   NaN
#
#           ClaimAmount   ClaimDate DiagnosisCode ProcedureCode    PatientAge  \
# ...

# %%
missing = df.isnull().sum()

print(missing)

plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# ClaimID                        0
# PatientID                      0
# ProviderID                     0
# ClaimAmount                    0
# ClaimDate                      0
# DiagnosisCode                  0
# ProcedureCode                  0
# PatientAge                     0
# PatientGender                  0
# ProviderSpecialty          15500
# ClaimStatus                    0
# PatientIncome              15500
# PatientMaritalStatus       15500
# PatientEmploymentStatus    15500
# ProviderLocation               0
# ClaimType                      0
# ClaimSubmissionMethod      15500
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %%
unique = pd.DataFrame({
    "Column": df.columns,
    "Unique Values": df.nunique().values
})

display(unique)
# Out:
#                      Column  Unique Values
# 0                   ClaimID          20000
# 1                 PatientID          18132
# 2                ProviderID           4500
# 3               ClaimAmount          19986
# 4                 ClaimDate           3635
# 5             DiagnosisCode           4495
# 6             ProcedureCode           4495
# 7                PatientAge            100
# 8             PatientGender              4
# 9         ProviderSpecialty              5
# 10              ClaimStatus              3
# 11            PatientIncome           4500
# 12     PatientMaritalStatus              4
# 13  PatientEmploymentStatus              4
# 14         ProviderLocation           3876
# 15                ClaimType              4
# 16    ClaimSubmissionMethod              3

# %%
num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
cat_cols = df.select_dtypes(include="object").columns

for col in cat_cols:
    if df[col].nunique() <= 20:
        plt.figure(figsize=(8,4))
        sns.countplot(y=df[col], order=df[col].value_counts().index)
        plt.title(col)
        plt.show()

# %%
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title("Boxplot of " + col)
    plt.show()

# %%
corr = df[num_cols].corr(numeric_only=True)

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
clean_df = df.drop_duplicates()

clean_df.to_csv("/content/enhanced_health_insurance_claims_FINAL_20000_cleaned.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.
